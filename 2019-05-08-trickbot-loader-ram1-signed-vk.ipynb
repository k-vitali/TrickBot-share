# %%
# TrickBot Loader gtag ram1
# MD5: c14d18adaf5e39b3d54138d03c904e72

import base64

data = '...'
key = '3oIC5btgDZX87znQcP9khJeSdqMNyHmxV4rWis/af6Rw1GOjL+0EY2FATKpBUlvu'
std_b64 = "ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789+/"

for s in data.split('/x00'):
    s = s.translate(str.maketrans(key,std_b64))
    if len(s)%4 != 0:
        s += '='*(4 - len(s)%4)
    print(base64.b64decode(s))
# Out:
# b'shell32.dll'
# b'ntdll.dll'
# b'shlwapi.dll'
# b'advapi32.dll'
# b'B64'
# b'svchost.exe'
# b'\\GpuSettings'
# b'cmdvrt32.dll'
# b'vmcheck.dll'
# b'dbghelp.dll'
# b'wpespy.dll'
# b'api_log.dll'
# b'SbieDll.dll'
# b'SxIn.dll'
# b'dir_watch.dll'
# b'Sf2.dll'
# b'pstorec.dll'
# b'snxhk.dll'
# b'MSEDGE'
# b'IEUser'
# b'SOFTWARE\\Microsoft\\Windows NT\\CurrentVersion\\'
# b'ProductName'
# b'Evaluation'
# b'SOFTWARE\\Microsoft\\Virtual Machine'
# b'{3E5FC7F9-9A51-4367-9063-A120244FBEC7}'
# b'{6EDD6D74-C007-4E75-B76A-E5740995E24C}'
# b'explorer.exe'
# b'bloody booty bla de bludy botty bla lhe capitaine bloode!'
# b'ole32.dll'
# b'wtsapi32'
# b'WTSEnumerateSessionsA'
# b'WTSFreeMemory'
# b'WTSGetActiveConsoleSessionId'
# b'WTSQueryUserToken'
# b'SeTcbPrivilege'
# b'Elevation:Administrator!new:'
# b'.log'
# b'client_id'
# b'%d%d%d.'
# b'user32.dll'
# b'CLSIDFromString'
# b'IIDFromString'
# b'C:\\Program Files\\Sophos\\Sophos System Protection\\ssp.exe'
# b'cmd.exe'
# ...

# %%
# TrickBot Core gtag ram1
import base64

data = '...'
key = '/w1FLnpxBJP3+gjo6dlrW9mUOSsIbiA8ETDaNXyVkeG7z0YCQc4huHZ5q2RMtKfv'
std_b64 = "ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789+/"

for s in data.split('/x00'):
    s = s.translate(str.maketrans(key,std_b64))
    if len(s)%4 != 0:
        s += '='*(4 - len(s)%4)
    print(base64.b64decode(s))
# Out:
# b'checkip.amazonaws.com'
# b'ipecho.net'
# b'ipinfo.io'
# b'api.ipify.org'
# b'icanhazip.com'
# b'myexternalip.com'
# b'wtfismyip.com'
# b'ip.anysrc.net'
# b'api.ipify.org'
# b'api.ip.sb'
# b'ident.me'
# b'www.myexternalip.com'
# b'/plain'
# b'/ip'
# b'/raw'
# b'/text'
# b'/?format=text'
# b'zen.spamhaus.org'
# b'cbl.abuseat.org'
# b'b.barracudacentral.org'
# b'dnsbl-1.uceprotect.net'
# b'spam.dnsbl.sorbs.net'
# b'Global\\First'
# b'Global\\%08lX%04lX%lu'
# b'%s sTart'
# b'%s %s'
# b'.tmp'
# b'CI failed, 0x%x'
# b'GET'
# b'path'
# b'Data\\'
# b'tmp'
# b'SINJ'
# b'SeTcbPrivilege'
# b'explorer.exe'
# b'/%s/%s/23/%d/'
# b'%s.%s.%s.%s'
# b'%s%s_configs\\'
# b'%s%s'
# b'wtsapi32'
# b'WTSEnumerateSessionsA'
# b'WTSFreeMemory'
# b'WTSGetActiveConsoleSessionId'
# b'WTSQueryUserToken'
# b'%s/%s/63/%s/%s/%s/%s/'
# b'noname'
# b'%s.%s'
# b'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.2228.0 Safari/537.36'
# b'Unknown'
# b'Windows 2000'
# ...
